# %%
import os
import platform
import pandas as pd
import pywt

# %%
cwd = os.getcwd()
df = pd.read_csv(cwd + "/CSV/mem1.csv")
testValues = df['Value'].to_list()
T , D = pywt.dwt(testValues, 'haar')
while len(T) > 1:
    testValues = T
    T , D = pywt.dwt(testValues, 'haar')
print('-----------------------------------')
print('|      T         |        D       |')
print('|---------------------------------|')
print('|' ,T, '|' , D, '|')
# Out:
# -----------------------------------
# |      T         |        D       |
# |---------------------------------|
# | [539.19259611] | [11.52994428] |
